# %% [markdown]
# <a href="https://colab.research.google.com/github/Cuddlehope/doggobox/blob/master/Copy_of_seaborn_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. Run this code:
# #### 1a. Imports

# %% [markdown]
# # Seaborn lab
#
# ## by Joanna Lankester, PhD
# ## CS 48A
#
# Instructions:
#
# - There are 26 numbered items; be sure to run them starting from the beginning so that the modules and variables you need will be available.
# - Items with a * require an answer (code or response), while the remaining items only need to be run in order to make the project work.
#     - For code, replace the three dots ... with your answer
#     - For responses, replace the text that says, _Type your answer here, replacing this text._
# - Do not replace or modify any text outside of these responses. Otherwise your responses may not receive credit.
#
# ## **Please title all plots with a description, and label all axes (item 4 and on). Include units when applicable.**
#
# Note: many of these titles and axes can be copy-pasted

# %%
import pandas as pd
import numpy as np
import seaborn as sns

sns.set_style("ticks")

# %% [markdown]
# #### 1b. Datasets

# %%
possum = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/DAAG/possum.csv")
vocab = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/carData/Vocab.csv")

ice_cream_dict = {"Shop": ['Cold Stone','Baskin Robbins','Tin Pot Creamery','Cream'],"Chocolate": [-2,4,0,1],"Vanilla":[4,2,1,4],"Mango":[3,-3,-4,-2],"Mint":[-4,1,1,0],"Pistachio":[1,2,1,-3]}
ice_cream = pd.DataFrame(ice_cream_dict)
ice_cream.set_index("Shop",inplace=True)

# %% [markdown]
# ### 2. Look at data
# The possum data frame consists of nine morphometric measurements on each of
# 104 mountain brushtail possums, trapped at seven sites from Southern Victoria
# to central Queensland (and measured, then released).
# Run this code to see what the possum dataset looks like:

# %%
possum.head()
# Out:
#   rownames  case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  \
# 0       C3     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0
# 1       C5     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5
# 2      C10     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0
# 3      C15     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0
# 4      C23     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0
#
#    footlgth  earconch   eye  chest  belly
# 0      74.5      54.5  15.2   28.0   36.0
# 1      72.5      51.2  16.0   28.5   33.0
# 2      75.4      51.9  15.5   30.0   34.0
# 3      76.1      52.2  15.2   28.0   34.0
# 4      71.0      53.2  15.1   28.5   33.0

# %% [markdown]
# ## Scatter plots

# %% [markdown]
# ### 3. Here is the code for a scatterplot in seaborn:
# `sns.scatterplot(x="hdlngth",y="skullw",data=possum)`
#
# Notice that the syntax includes the names of the columns "in quotes",
# but the name of the dataframe, possum, is not in quotes.
#
# We will build off this code for the next few questions.

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 4*. Edit title and axis labels
#
# We will now save the result of the previous plot to a variable so we can modify it:
#
# `ax = sns.scatterplot(x="hdlngth",y="skullw",data=possum)`
#
# These Matplotlib commands allow us to modify some features of the plot:
#
# `ax.set_title("Your title here")
# ax.set_xlabel("your x axis label with units")
# ax.set_ylabel("your y axis label with units")`
#
# This plot is of skull width vs head length of 104 mountain brushtail possums.
# Copy and paste the four lines of code provided.
# Modify the title and axis labels. Remember to include units on the axes (mm).
#
# You may want to copy, paste, and modify these labels and title on later plots.
#
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q4 -->

# %%
ax = sns.scatterplot(x="hdlngth",y="skullw",data=possum)
ax.set_title("Skull width vs. head length of 104 mountain brushtail possums, AS")
ax.set_xlabel("Head length (mm)")
ax.set_ylabel("Skull width (mm)")
# Out:
# Text(0, 0.5, 'Skull width (mm)')

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 5*. Add a third dimension to encode age using the size of the dots.
# Include `size="age"` in the list of options you give to scatterplot, in addition to the x and y options.
#
# Label the title and axes appropriately (note: age is in years).
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q5 -->

# %%
ax = sns.scatterplot(x="hdlngth",y="skullw",size = "age",data=possum)
ax.set_title("Skull width vs. head length in 104 mountain brushtail possums of various ages, shown by circle size, AS")
ax.set_xlabel("Head length (mm)")
ax.set_ylabel("Skull width (mm)")
ax.get_legend().set_title("Age (years)")

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 6*. Next, encode the age of each possum as color (hue) instead of size.
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q6 -->

# %%
ax = sns.scatterplot(x="hdlngth",y="skullw",hue = "age",data=possum)
ax.set_title("Skull width vs. head length of 104 mountain brushtail possums, colored by age, AS")
ax.set_xlabel("Head length (mm)")
ax.set_ylabel("Skull width (mm)")
ax.get_legend().set_title("Age (years)")

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 7*. Next, encode the sex of each possum as hue, instead of the age.
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q7 -->

# %%
ax = sns.scatterplot(x="hdlngth",y="skullw",hue = "sex",data=possum)
ax.set_title("Skull width vs. head length in 104 mountain brushtail possums, colored by sex, AS")
ax.set_xlabel("Head length (mm)")
ax.set_ylabel("Skull width (mm)")
ax.get_legend().set_title("Sex")

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 8*. Next, encode the sex of each possum as both hue and the shape of the marker.
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q8 -->

# %%
ax = sns.scatterplot(x="hdlngth",y="skullw",style = "sex", hue = "sex",data=possum)
ax.set_title("Skull width vs. head length of 104 mountain brushtail possums, with sex shown by color and shape, AS")
ax.set_xlabel("Head length (mm)")
ax.set_ylabel("Skull width (mm)")
ax.get_legend().set_title("Sex")

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# ### 9 (response only)*.
# Finally, let's see how the skull width and head length are correlated.
# Here is the plot with a best-fit line. Run this code and answer the question below.

# %%
ax = sns.regplot(x="hdlngth",y="skullw",data=possum)
ax.set_xlabel("head length (mm)")
ax.set_ylabel("skull width (mm)")
ax.set_title("Relationship between dimensions of brush tailed possums")
# Out:
# Text(0.5, 1.0, 'Relationship between dimensions of brush tailed possums')

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# #### Question 9:
# Is the correlation positive or negative, and how do you know?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q9 -->

# %% [markdown]
# _The correlation is positive because as the head length (x) increases, the skull width increases as well (y). As x increases when y increases, head length and skull width have a positive correlation. It is also shown that the line of best fit has a positive slope._

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# ## Distributions

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 10*. Label a histogram.
# Run this code to plot a histogram of the ages
# of the possums.
# Add code to label the x axis and title appropriately. (Remember to specify units!)
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q10 -->

# %%
ax = sns.histplot(x="age",data=possum)
ax.set_ylabel('frequency')
ax.set_xlabel('age (years)')
ax.set_title('Distribution of the ages of mountain brushtail possums, AS');

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 11*. Modify a histogram.
# The above histogram is misleading since the ages are whole integer numbers.
# We can't tell whether the count reflected is the age on the left or the right.
# It would be better to plot each bar centered at the integer number. This will
# also avoid the potential problem of having two ages combined at one end of the range.
#
# Copy and paste the code from above, and modify the plot by adding the "discrete"
# command.
# Reference page: https://seaborn.pydata.org/generated/seaborn.histplot.html
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q11 -->

# %%
ax = sns.histplot(x="age", discrete = True, binwidth = 1,data=possum)
ax.set_ylabel('frequency')
ax.set_xlabel('age (years)')
ax.set_title('Distribution of the ages of mountain brushtail possums, AS');

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 12 (two responses)*. Based on the plot above:
# What was the most common age of the possums?
# What was the second most common age?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q12 -->

# %% [markdown]
# _The most common age is 3 years old while the second most common age is 2 years old._

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 13*. Create a violin plot of the length of the possums at each site.
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q13 -->

# %%
ax = sns.violinplot(x="site", y = "totlngth", data=possum)
ax.set_ylabel('Total Length (cm)')
ax.set_xlabel('Site')
ax.set_title('Length of possums at each site, AS');

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 14 (response)*.
# Based on your violin plot, the shortest of all the possums live at which site number?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q14 -->

# %% [markdown]
# _The shortest of all the possums lives at site number 2. _

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ## Time series

# %% [markdown]
# ### 15. Run this code to see what the vocabulary dataset looks like.
# This is a slightly larger dataset, about 30,000 rows.

# %%
vocab.head()
# Out:
#    rownames  year     sex  education  vocabulary
# 0  19740001  1974    Male         14           9
# 1  19740002  1974    Male         16           9
# 2  19740003  1974  Female         10           9
# 3  19740004  1974  Female         10           5
# 4  19740005  1974  Female         12           8

# %% [markdown]
# ### 16. Run this code to summarize the vocab by year and see the results:

# %%
vocab_summary_by_year = vocab.groupby("year")[['education','vocabulary']].mean()
vocab_summary_by_year.reset_index(inplace=True)
vocab_summary_by_year.head()
# Out:
#    year  education  vocabulary
# 0  1974  11.874827    6.024205
# 1  1976  11.840084    6.053073
# 2  1978  12.043801    5.964960
# 3  1982  12.211259    5.741149
# 4  1984  12.510394    6.024373

# %% [markdown]
# ### 17. Create line plots
# Create line plots to see how education and vocabulary have changed over
# the years. You will not use the vocab dataset! Instead, you will use the
# vocab_summary_by_year dataset, which has already aggregated the values from
# the original vocab dataset.
# Don't forget labels!
#
# Hint: the x-axis should have the year.
#
# Hint: Look up the dataset here so that you can put units on the labels:
# https://vincentarelbundock.github.io/Rdatasets/doc/carData/Vocab.html

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 17a*. Education line plot:
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q17a -->

# %%
ax = sns.lineplot(x="year",y="education",data= vocab_summary_by_year)
ax.set_ylabel('Average education (years)')
ax.set_xlabel('Year')
ax.set_title('Changes in education of U.S. General Social Survey respondents, AS');

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 17b*. Vocabulary line plot:
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q17b -->

# %%
ax = sns.lineplot(x="year",y="vocabulary",data= vocab_summary_by_year)
ax.set_ylabel('Vocabulary test score (number correct out of 10)')
ax.set_xlabel('Year')
ax.set_title('Vocabulary test score (10 word test) changes over the years of U.S. General Social Survey respondents, AS');

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ### 17c (response only)*.
# Have education and vocabulary both changed? Does change in education at this
# point seem to relate to vocabulary scores?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q17c -->

# %% [markdown]
# Education and vocabulary have changed in different ways. They seem to not relate to each other as education rose steadily compared to vocabulary, which has spikes and dips but seems to fluctuate around 6.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ### 18.
# We'd like to see more detail about how education and
# vocabulary score relate. Look again at the **original vocab data frame** to answer these questions:

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# #### 18a (response only)*.
# Considering the 4 data types we learned about in the first week, what is the data type of the education variable?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q18a -->

# %% [markdown]
# Discrete quantitative data (years of education are measured in whole years).

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# #### 18b (response only)*. What is the data type of the vocabulary variable?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q18b -->

# %% [markdown]
# Discrete quantitative data.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# #### 18c (response only)*. Run the following code to generate a scatterplot.
# Answer the question below.

# %%
vocab_scatterplot = sns.scatterplot(x="education",y="vocabulary",data=vocab)
vocab_scatterplot.set_xlabel("education (years)")
vocab_scatterplot.set_ylabel("vocabulary test score (out of 10)")
# Out:
# Text(0, 0.5, 'vocabulary test score (out of 10)')

# %% [markdown]
# ##### Question 18c
# Hmm, this plot does not give us much information. Why not?
# What is it about this plot that makes it impossible for us to see the
# underlying information? (Please be as specific as possible. Consider modules
# on scatter plots.)
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q18c -->

# %% [markdown]
# There are over 30,000 entries/data points that should be displayed. However, we don't see nearly 30,000 dots on our scatter plot. They are overlapped, but we can't tell simply by looking at it. Specifically, they are discrete integers, so when they overlap, they overlap completely. This overlap makes it impossible to see the frequency at each spot and the trend. There are only hundreds of spots, but there are over 30,000 data points.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ### 19.
# Here are two more ways of visualizing the relationship between education
# and vocabulary. What information do each of these plots give in terms of
# understanding the relationship between these two variables?
# #### 19a (response only)*
#
# Run this code and answer the questions below about the plot.
#
# Note: this may take a moment to run, due to the data size and particular plot type

# %%
plot19a = sns.jointplot(x="education", y="vocabulary", data=vocab,kind="hist", discrete=True,cbar=True)
plot19a.set_axis_labels("education (years)","vocabulary (score out of 10)")
plot19a.fig.suptitle("Plot 19a")
# Out:
# Text(0.5, 0.98, 'Plot 19a')

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
#
# ##### Questions for 19a
# - Identify the plot type shown on the middle and edges of the plot.
# - What observations do you make about the individual distributions of education and vocabulary?
# - What conclusion do you draw from this plot?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q19a -->

# %% [markdown]
# In the middle, there is a heat map, colored by how many people fall in it. On the edges of the plot, there are histograms of education and vocabulary.
# Looking at the individual distributions of education and vocabulary, I see that there are peaks in the histograms. It seems like there are 2 spikes in education years. For vocabulary, it looks more like a symmetrical distribution that peaks around a score of 6.
# I can draw a conclusion that there seems to be more people with 12 years of education and then 16 years. A concentration of navy blue is in the heatmap at a concentrated area of 12 years of education and vocabulary score of 6. I can see a faint trend of positive correlation of the heat map.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
#
#
# #### 19b (response only)*
#
# Run this code and answer the questions below about the plot.

# %%
plot19b = sns.jointplot(x="education",y="vocabulary",data=vocab,kind="reg")
plot19b.set_axis_labels("education (years)","vocabulary (score out of 10)")
plot19b.fig.suptitle("Plot 19b")
# Out:
# Text(0.5, 0.98, 'Plot 19b')

# %% [markdown]
# <!-- BEGIN INSTRUCTIONS -->
#
# ##### Questions for 19b
# - What elements have been added to the original plot?
# - What would you conclude from this plot?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q19b -->

# %% [markdown]
# There is now a linear regression line added to the scatter plot, and histograms with density curves are also added for education and vocabulary. I can conclude that there is a positive correlation between education and vocabulary.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# #### 19c (response only)*.
# What do you conclude about the relationship between
# education and vocabulary score on this test?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q19c -->

# %% [markdown]
# They have a positive correlation! More education is correlated with higher vocabulary scores.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ## Heat map

# %% [markdown]
# ### 20 (response only)*.
# Run this code to see the ice cream dataset, and answer the question below.

# %%
ice_cream
# Out:
#                   Chocolate  Vanilla  Mango  Mint  Pistachio
# Shop
# Cold Stone               -2        4      3    -4          1
# Baskin Robbins            4        2     -3     1          2
# Tin Pot Creamery          0        1     -4     1          1
# Cream                     1        4     -2     0         -3

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# Is this long or wide data?
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q20 -->

# %% [markdown]
# This is wide data as the categorical variable, flavor, is used as a column name.

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ### 21. Display a heat map.
# This data is already in the correct form for plotting in a heat map. Run this
# code to see what the default heat map of this data looks like.

# %%
plot21 = sns.heatmap(ice_cream,center=0)
plot21.set_title("Changes in ice cream units stocked since yesterday")
plot21.set_xlabel("Flavor")
# Out:
# Text(0.5, 23.52222222222222, 'Flavor')

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# ### 22*. Customize this heat map by making both of these changes:
#
# - Turn on annotations (annot=True)
# - Specify a color map (cmap=) with an appropriate color map option.
#
# Here are some example color maps:
# https://matplotlib.org/stable/users/explain/colors/colormaps.html#classes-of-colormaps
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q22 -->

# %%
plot21 = sns.heatmap(ice_cream,annot=True,cmap='managua',center=0)
plot21.set_title("Changes in ice cream units stocked since yesterday")
plot21.set_xlabel("Flavor")
# Out:
# Text(0.5, 23.52222222222222, 'Flavor')

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# ## Aesthetics

# %% [markdown]
# ### 23. Demo code.
# Run this code to get a plot that, despite being not too informative from a data perspective, will give us an example where we can see available colors clearly.

# %%
vocab_subset = vocab[vocab['year'] > 2000]
sns.violinplot(x="year",y="education",data=vocab_subset)
# Out:
# <Axes: xlabel='year', ylabel='education'>

# %% [markdown]
# ### 24. Code for changing style and palette.
# Run this code to change the appearance of plots from here on.

# %%
sns.set(style='darkgrid',palette='deep')

# %% [markdown]
# ### 25. Code for demonstrating style and palette.
# Re-run this code to see how the plot looks different.

# %%
sns.violinplot(x="year",y="education",data=vocab_subset)
# Out:
# <Axes: xlabel='year', ylabel='education'>

# %% [markdown]
# ### 26*. Practice changing styles and palettes.
# Now choose 2 combinations of styles and palattes to try.
# Set them using the set command, and then see the change in the copy of the violinplot command from above. Run both lines of code to see how your plot looks!
# (Note: do not worry about adding titles/labels for this part)
#
# - Styles: whitegrid, darkgrid, dark, white, ticks
# - Palettes: deep, muted, pastel, bright, dark, and colorblind.

# %% [markdown]
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# #### 26a*. Your first style/palette combination:
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q26a -->

# %%
sns.set(style='white',palette='pastel')
sns.violinplot(x="year",y="education",data=vocab_subset)
# Out:
# <Axes: xlabel='year', ylabel='education'>

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
# <!-- BEGIN QUESTION -->
# <!-- BEGIN INSTRUCTIONS -->
# #### 26b*. Your second style/palette combination:
# <!-- END INSTRUCTIONS -->
# <!-- BEGIN RESPONSE -->
# <!-- Q26b -->

# %%
sns.set(style='whitegrid',palette='bright')
sns.violinplot(x="year",y="education",data=vocab_subset)
# Out:
# <Axes: xlabel='year', ylabel='education'>

# %% [markdown]
# <!-- END RESPONSE -->
# <!-- END QUESTION -->
#
# END OF SEABORN LAB - DO NOT DELETE THIS CELL
